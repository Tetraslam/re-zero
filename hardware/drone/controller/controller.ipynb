# %%
# Cell 1: start heartbeat + control stream (background threads)
from drone import start_drone

drone = start_drone(verbose=True)
# Out:
# [HB] local=('192.168.0.2', 6000) -> 192.168.0.1:40000 hz=1.0
# [CTRL] local=('192.168.0.2', 5010) -> 192.168.0.1:40000 hz=22.3
# [CTRL] waiting for telemetry...
# [RX] udp src=40000 len=106 head=63630136006300524144434c4f465056
# [CTRL] telemetry seen; control stream running
# [RX] udp src=40000 len=106 head=63630137006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630139006300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363013a006300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363013b006300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363013c006300524144434c4f465056

# %%
# Cell 2: send commands
# Warning: these affect a real drone.
drone.takeoff()
# Out:
# [RX] udp src=40000 len=106 head=6363014e006300524144434c4f465056

# %%
drone.land()
# Out:
# [RX] udp src=40000 len=106 head=63630142006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630144006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630146006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630148006300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363014a006300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363014c006300524144434c4f465056

# %%
drone.estop()
# Out:
# [RX] udp src=40000 len=106 head=63630150006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630152006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630154006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630156006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630158006300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363015a006300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363015c006300524144434c4f465056
# [RX] udp src=40000 len=106 head=6363015e006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630160006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630162006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630164006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630166006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630167006300524144434c4f465056
# [RX] udp src=40000 len=106 head=63630168006300524144434c4f465056
# ...
